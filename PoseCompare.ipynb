# %%
# !git clone https://github.com/open-mmlab/mmcv.git
# !git clone https://github.com/ViTAE-Transformer/ViTPose.git
# !git clone https://github.com/shubham-goel/4D-Humans.git FDHumans
# Out:
# fatal: destination path 'mmcv' already exists and is not an empty directory.
# fatal: destination path 'ViTPose' already exists and is not an empty directory.
# fatal: destination path 'FDHumans' already exists and is not an empty directory.

# %% [markdown]
# Make conda environment: Run the following lines in a terminal

# %% [markdown]
# conda activate PoseCompare
# cd mmcv
# git checkout v1.3.9
# # For Unix:
# MMCV_WITH_OPS=1 pip install -e .
# # For windows CMD LINE:
# set MMCV_WITH_OPS=1 && pip install -e .
#
# # if you experience error with mmcv and mmcv-full install: try the following
# pip uninstall mmcv mmcv-full
# pip install mmcv-full==1.4.8 -f https://download.openmmlab.com/mmcv/dist/cu113/torch1.11.0/index.html
#
# cd ..
# git clone https://github.com/ViTAE-Transformer/ViTPose.git
# cd ViTPose
# pip install -v -e .
#
# mkdir checkpoints
# cd ./checkpoints
# curl.exe -L -o vitpose_checkpoint.pth "https://62afda.dm.files.1drv.com/y4mBDiqHvl4ClkQbjljDfxZ35JemNwe-D-YlTuMfeya1BIR5tVP3cO26ntjrJkBL-2L8beSmOOPy7149gWRMkDqTZCPhS--XxryYZLSGtdKxR5ADq-9S_6ApoHxLbQP4MOs63iPz2jSLQMFqJFcFdoXZ2ml2HyvGkCu7MxyP9ELoZvtYRyipBDvsFvR2bN7xUknS6LR5HdBjGpZtM7saMmIXQ"

# %% [markdown]
# cd 4DHumans
# pip install -e .[all]
# # if detectron2 failed to install, try install it directly:
# pip install git+https://github.com/facebookresearch/detectron2
#
# pip install git+https://github.com/brjathu/PHALP.git
#
# wget https://github.com/classner/up/raw/821a390fbf87a522fb327fc46736eda0326e2a06/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# mkdir data/
# cp basicModel_neutral_lbs_10_207_0_v1.0.0.pkl ./data/

# %%
import os

print("Current working directory:", os.getcwd())
# Out:
# Current working directory: /home/bizon/dong/PoseCompare

# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import tkinter as tk
from tkinter import ttk, filedialog
import cv2
import numpy as np
from PIL import Image, ImageTk
import mediapipe as mp
import sys
import logging
import torch
import torchvision.transforms as transforms
from collections import OrderedDict
from mmcv import Config
from mmpose.models import build_posenet
from mmcv.runner import load_checkpoint

# Increase recursion limit
sys.setrecursionlimit(10000)
# Out:
# apex is not installed
# apex is not installed
# apex is not installed
# /home/bizon/dong/PoseCompare/mmcv/mmcv/cnn/bricks/transformer.py:27: UserWarning: Fail to import ``MultiScaleDeformableAttention`` from ``mmcv.ops.multi_scale_deform_attn``, You should install ``mmcv-full`` if you need this module.
#   warnings.warn('Fail to import ``MultiScaleDeformableAttention`` from '

# %%
class VitPoseWrapper:
    """Wrapper for ViTPose model."""
    def __init__(self, config_path, weights_path, input_size=(192, 256), device=None):
        self.input_width, self.input_height = input_size
        self.device = device or torch.device('cuda' if torch.cuda.is_available() else 'cpu')

        try:
            # Load configuration and model
            cfg = Config.fromfile(config_path)
            self.model = build_posenet(cfg.model)
            load_checkpoint(self.model, weights_path, map_location=self.device)
            self.model.to(self.device)
            self.model.eval()

            # Transformation pipeline
            self.transform = transforms.Compose([
                transforms.ToTensor(),
                transforms.Normalize(
                    mean=[0.485, 0.456, 0.406],
                    std=[0.229, 0.224, 0.225]
                )
            ])

            # Keypoint connections (COCO format)
            self.keypoint_connections = [
                (15, 13), (13, 11), (16, 14), (14, 12),  # Limbs
                (11, 12), (5, 11), (6, 12), (5, 6),      # Hips to shoulders
                (5, 7), (6, 8), (7, 9), (8, 10),        # Neck to arms
                (1, 2), (0, 1), (0, 2), (1, 3), (2, 4), (3, 5), (4, 6)  # Face and shoulders
            ]

            logging.info("ViTPose model initialized successfully.")
        except Exception as e:
            logging.error(f"Failed to initialize ViTPose model: {e}")
            raise

    def preprocess_frame(self, frame):
        """Preprocess frame for model input."""
        try:
            original_height, original_width = frame.shape[:2]
            
            # Simple resize to model input size
            frame_resized = cv2.resize(frame, (self.input_width, self.input_height))
            frame_rgb = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2RGB)
            input_tensor = self.transform(frame_rgb).unsqueeze(0).to(self.device)

            # Store metadata for rescaling predictions back to original size
            img_metas = [{
                'img_shape': (self.input_height, self.input_width, 3),
                'original_shape': (original_height, original_width, 3),
                'scale_factor': np.array([
                    original_width / self.input_width,
                    original_height / self.input_height
                ]),
                'center': np.array([self.input_width // 2, self.input_height // 2]),
                'scale': np.array([1.0, 1.0]),
                'rotation': 0,
                'flip_pairs': None,
                'dataset_idx': 0,
                'image_file': None
            }]
            return input_tensor, img_metas
        except Exception as e:
            logging.error(f"Error preprocessing frame: {e}")
            return None, None

    def process_frame(self, frame):
        """Run inference on a single frame and return keypoints."""
        try:
            input_tensor, img_metas = self.preprocess_frame(frame)
            if input_tensor is None:
                return None

            with torch.no_grad():
                output = self.model(img=input_tensor, img_metas=img_metas, return_loss=False)
                return output['preds'][0]  # Extract keypoints for the first person
        except Exception as e:
            logging.error(f"Error processing frame with ViTPose: {e}")
            return None

# %%
import warnings
from dataclasses import dataclass
from pathlib import Path
from typing import Optional, Tuple

from FDHumans.hmr2.models import load_hmr2, DEFAULT_CHECKPOINT
from FDHumans.hmr2.utils import recursive_to
import logging
warnings.filterwarnings('ignore')

# %%
class FourDHumanWrapper:
    """Wrapper for 4DHuman model."""
    
    def __init__(self, checkpoint_path=None, device=None):
        """
        Initialize the 4DHuman model.

        Args:
            checkpoint_path (str): Path to the model checkpoint.
            device (torch.device): Device to load the model on (CPU or GPU).
        """
        self.device = device or torch.device('cuda' if torch.cuda.is_available() else 'cpu')
        self.checkpoint_path = checkpoint_path or DEFAULT_CHECKPOINT

        try:
            # Load the model and move to device
            self.model, self.model_cfg = load_hmr2(self.checkpoint_path)
            self.model.to(self.device)
            self.model.eval()

            logging.info("4DHuman model initialized successfully.")
        except Exception as e:
            logging.error(f"Failed to initialize 4DHuman model: {e}")
            raise

    def preprocess_frame(self, frame):
        """
        Preprocess a video frame for the 4DHuman model.

        Args:
            frame (np.ndarray): Input frame in BGR format.

        Returns:
            torch.Tensor: Preprocessed frame as a tensor.
        """
        try:
            frame_resized = cv2.resize(frame, (224, 224))
            frame_rgb = cv2.cvtColor(frame_resized, cv2.COLOR_BGR2RGB) / 255.0
            input_tensor = torch.tensor(frame_rgb.transpose(2, 0, 1), dtype=torch.float32).unsqueeze(0)
            return input_tensor.to(self.device)
        except Exception as e:
            logging.error(f"Error preprocessing frame: {e}")
            return None

    def process_frame(self, frame):
        """
        Run inference on a single frame and return the human mesh and other predictions.

        Args:
            frame (np.ndarray): Input frame in BGR format.

        Returns:
            dict: Model output, including vertices and camera parameters.
        """
        try:
            # Preprocess the frame
            input_tensor = self.preprocess_frame(frame)
            if input_tensor is None:
                return None

            # Run inference
            with torch.no_grad():
                batch = {"img": input_tensor}
                batch = recursive_to(batch, self.device)
                output = self.model(batch)
            
            return output
        except Exception as e:
            logging.error(f"Error processing frame with 4DHuman model: {e}")
            return None

    def render_mesh(self, frame, vertices, camera_params):
        """
        Render the human mesh on the input frame.

        Args:
            frame (np.ndarray): Original frame (BGR format).
            vertices (np.ndarray): 3D vertices of the mesh (6890, 3).
            camera_params (np.ndarray): Camera parameters for projection.

        Returns:
            np.ndarray: Frame with rendered mesh.
        """
        try:
            s, tx, ty = camera_params  # Scale and translation
            img_h, img_w = frame.shape[:2]
            projected_vertices = vertices[:, :2] * s + np.array([tx, ty])
            projected_vertices[:, 0] = (projected_vertices[:, 0] + 1) * img_w / 2.0
            projected_vertices[:, 1] = (1 - projected_vertices[:, 1]) * img_h / 2.0

            # Draw the vertices on the frame
            mesh_frame = frame.copy()
            for v in projected_vertices.astype(int):
                cv2.circle(mesh_frame, tuple(v), 2, (0, 255, 0), -1)  # Green dots for vertices
            
            return mesh_frame
        except Exception as e:
            logging.error(f"Error rendering mesh: {e}")
            return frame
        
    def get_display_frame(self, frame):
        """Process the frame and return the rendered mesh frame."""
        try:
            output = self.process_frame(frame)
            if output is not None:
                vertices = output["pred_vertices"][0].cpu().numpy()
                camera_params = output["pred_cam"][0].cpu().numpy()
                return self.render_mesh(frame, vertices, camera_params)
        except Exception as e:
            logging.error(f"Error generating display frame: {e}")
        return frame

# %%
class PoseEstimationUI:
    def __init__(self, root,vitpose_weights_path = None, fourDHuman_weight_path = None, vitpose_config_path = None):
        
        self.root = root
        self.root.title("Pose Estimation Comparison")
        self.vitpose_weights_path = vitpose_weights_path
        self.vitpose_config_path = vitpose_config_path
        self.fourDHuman_weight_path = fourDHuman_weight_path
        # Video state
        self.video_path = None
        self.cap = None
        self.playing = False
        self.current_frame = 0
        self.total_frames = 0
        self.frame_cache = {}  # Cache for loaded frames
        
        # Initialize models
        self.setup_models()
        
        # Create UI elements
        self.create_ui()
        
        # Update timer
        self.update_interval = 30  # milliseconds
        self.update_id = None

        self.view_states = {
            'mediapipe': {'show_background': True},
            'vitpose': {'show_background': True},
            '4dhuman': {'show_background': True}
        }
        
    def setup_models(self):
        """Initialize pose estimation models"""
        try:
            self.FDHmodel = FourDHumanWrapper()
        except Exception as e:
            logging.error(f"Failed to initialize 4DHumans: {e}")
            self.FDHmodel = None
        try:
            self.mp_pose = mp.solutions.pose
            self.mp_drawing = mp.solutions.drawing_utils
            self.mediapipe_pose = self.mp_pose.Pose(
                static_image_mode=False,
                model_complexity=2,
                min_detection_confidence=0.5
            )
        except Exception as e:
            logging.error(f"Failed to initialize MediaPipe: {e}")
            self.mediapipe_pose = None
        # Load the model
        # cfg = Config.fromfile('ViTPose/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/ochu/vitpose_base_coco_256x192.py')
        # cfg = Config.fromfile('ViTPose/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/coco/vitPose+_small_coco+aic+mpii+ap10k+apt36k+wholebody_256x192_udp.py')
        # cfg = Config.fromfile('ViTPose/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/coco/vitPose+_base_coco+aic+mpii+ap10k+apt36k+wholebody_256x192_udp.py')
        # cfg = Config.fromfile('ViTPose/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/coco/vitPose+_large_coco+aic+mpii+ap10k+apt36k+wholebody_256x192_udp.py')

        # self.vitpose = build_posenet(cfg.model)
        # load_checkpoint(model, './ViTPose/weights/vitpose_large_coco_aic_mpii.pth', map_location='cpu')
        # load_checkpoint(model, './ViTPose/weights/vitpose+_small.pth', map_location='cpu')
        # load_checkpoint(self.vitpose,'./ViTPose/weights/vitpose+_base.pth',map_location='cpu')
        # try:
        #     load_checkpoint(model,'./ViTPose/weights/vitpose+_large.pth',map_location='cuda')
        # except Exception as e:
        #     load_checkpoint(model,'./ViTPose/weights/vitpose+_large.pth',map_location='cpu')

        # if self.vitpose_weights_path:  # You'll need to define this path
        #     try:
        #         self.vitpose = VitPoseWrapper(self.vitpose_weights_path)
        #         logging.info("VitPose model initialized successfully")
        #     except Exception as e:
        #         logging.error(f"Failed to initialize VitPose: {e}")
        try:
            # Initialize ViTPose
            config_path = self.vitpose_config_path
            weights_path = self.vitpose_weights_path
            self.vitpose_wrapper = VitPoseWrapper(config_path, weights_path)
        except Exception as e:
            logging.error(f"Failed to initialize ViTPose: {e}")
            self.vitpose_wrapper = None
    def create_ui(self):
        """Create the user interface"""
        # Main container
        main_container = ttk.Frame(self.root)
        main_container.pack(fill=tk.BOTH, expand=True)
        
        # Top control panel
        control_frame = ttk.Frame(main_container)
        control_frame.pack(fill=tk.X, padx=5, pady=5)

        # Add view toggle panel
        toggle_frame = ttk.Frame(main_container)
        toggle_frame.pack(fill=tk.X, padx=5, pady=2)
        
        # View toggle buttons
        ttk.Label(toggle_frame, text="View Options:").pack(side=tk.LEFT, padx=5)
        
        def create_toggle_button(model_name):
            var = tk.BooleanVar(value=True)
            btn = ttk.Checkbutton(
                toggle_frame,
                text=f"Show {model_name} Background",
                variable=var,
                command=lambda: self.toggle_view(model_name.lower(), var.get())
            )
            btn.pack(side=tk.LEFT, padx=5)
            return var
            
        self.toggle_vars = {
            'mediapipe': create_toggle_button('MediaPipe'),
            'vitpose': create_toggle_button('VitPose'),
            '4DHuman': create_toggle_button('4DHuman')
        }
        
        # Video display area
        display_frame = ttk.Frame(main_container)
        display_frame.pack(fill=tk.BOTH, expand=True, padx=5, pady=5)

        # Video selection
        self.file_button = ttk.Button(control_frame, text="Open Video", command=self.safe_open_video)
        self.file_button.pack(side=tk.LEFT, padx=5)
        
        # Playback controls
        self.prev_button = ttk.Button(control_frame, text="⏮", command=self.prev_frame)
        self.prev_button.pack(side=tk.LEFT, padx=2)
        
        self.play_button = ttk.Button(control_frame, text="▶", command=self.toggle_play)
        self.play_button.pack(side=tk.LEFT, padx=2)
        
        self.next_button = ttk.Button(control_frame, text="⏭", command=self.next_frame)
        self.next_button.pack(side=tk.LEFT, padx=2)
        
        # Frame slider
        self.frame_slider = ttk.Scale(control_frame, from_=0, to=100, orient=tk.HORIZONTAL)
        self.frame_slider.pack(side=tk.LEFT, fill=tk.X, expand=True, padx=5)
        self.frame_slider.bind("<ButtonRelease-1>", self.on_slider_release)
        
        # Frame counter
        self.frame_label = ttk.Label(control_frame, text="Frame: 0/0")
        self.frame_label.pack(side=tk.RIGHT, padx=5)
        
        # Video display area
        display_frame = ttk.Frame(main_container)
        display_frame.pack(fill=tk.BOTH, expand=True, padx=5, pady=5)
        
        # Configure grid
        display_frame.grid_columnconfigure((0,1,2,3), weight=1)
        display_frame.grid_rowconfigure(0, weight=1)
        
        # Create canvases for video display
        canvas_width = 320
        canvas_height = 240
        
        # Original video
        self.original_canvas = tk.Canvas(display_frame, width=canvas_width, height=canvas_height, bg='black')
        self.original_canvas.grid(row=0, column=0, padx=5, pady=5, sticky='nsew')
        ttk.Label(display_frame, text="Original").grid(row=1, column=0)
        
        # MediaPipe output
        self.mediapipe_canvas = tk.Canvas(display_frame, width=canvas_width, height=canvas_height, bg='black')
        self.mediapipe_canvas.grid(row=0, column=1, padx=5, pady=5, sticky='nsew')
        ttk.Label(display_frame, text="MediaPipe").grid(row=1, column=1)
        
        # VitPose output
        self.vitpose_canvas = tk.Canvas(display_frame, width=canvas_width, height=canvas_height, bg='black')
        self.vitpose_canvas.grid(row=0, column=2, padx=5, pady=5, sticky='nsew')
        ttk.Label(display_frame, text="VitPose").grid(row=1, column=2)

        # 4DHuman output
        self.fourdhuman_canvas = tk.Canvas(display_frame, width=canvas_width, height=canvas_height, bg='black')
        self.fourdhuman_canvas.grid(row=0, column=4, padx=5, pady=5, sticky='nsew')
        ttk.Label(display_frame, text="4DHuman").grid(row=1, column=4)

    def toggle_view(self, model_name, show_background):
        """Toggle between full view and skeleton/mesh only view"""
        self.view_states[model_name]['show_background'] = show_background
        self.update_frame()

    def safe_open_video(self):
        """Safely open video file dialog"""
        try:
            filename = filedialog.askopenfilename(
                filetypes=[("Video files", "*.mp4 *.avi *.mov *.mkv")]
            )
            if filename:
                self.load_video(filename)
        except Exception as e:
            logging.error(f"Error opening video: {e}")
            tk.messagebox.showerror("Error", f"Failed to open video: {str(e)}")
            
    def load_video(self, filename):
        """Load the selected video file"""
        try:
            if self.cap is not None:
                self.cap.release()
                self.cap = None
            
            self.cap = cv2.VideoCapture(filename)
            if not self.cap.isOpened():
                raise ValueError("Failed to open video file")
                
            self.video_path = filename
            self.total_frames = int(self.cap.get(cv2.CAP_PROP_FRAME_COUNT))
            self.current_frame = 0
            self.frame_cache.clear()
            
            # Update slider
            self.frame_slider.configure(to=self.total_frames - 1)
            self.frame_slider.set(0)
            
            # Update first frame
            self.update_frame()
            
        except Exception as e:
            logging.error(f"Error loading video: {e}")
            tk.messagebox.showerror("Error", f"Failed to load video: {str(e)}")
            
    def on_slider_release(self, event):
        """Handle slider release event"""
        try:
            self.current_frame = int(self.frame_slider.get())
            self.update_frame()
        except Exception as e:
            logging.error(f"Error updating frame: {e}")
            
    def toggle_play(self):
        """Toggle video playback"""
        if self.cap is None:
            return
            
        self.playing = not self.playing
        self.play_button.configure(text="⏸" if self.playing else "▶")
        
        if self.playing:
            self.play()
        elif self.update_id:
            self.root.after_cancel(self.update_id)
            self.update_id = None
            
    def safe_read_frame(self):
        """Safely read a frame from video"""
        try:
            if self.current_frame in self.frame_cache:
                return True, self.frame_cache[self.current_frame]
                
            self.cap.set(cv2.CAP_PROP_POS_FRAMES, self.current_frame)
            ret, frame = self.cap.read()
            
            if ret:
                self.frame_cache[self.current_frame] = frame
            
            return ret, frame
        except Exception as e:
            logging.error(f"Error reading frame: {e}")
            return False, None
            
    def update_frame(self):
        """Update frame display"""
        if self.cap is None:
            return
            
        ret, frame = self.safe_read_frame()
        if not ret:
            self.playing = False
            return
            
        try:
            # Update displays
            self.update_original_display(frame)
            self.update_mediapipe_display(frame.copy())
            self.update_vitpose_display(frame.copy())
            # self.update_wham_display(frame.copy())
            self.update_fourdhuman_display(frame.copy())

            # Update slider and label
            self.frame_slider.set(self.current_frame)
            self.frame_label.configure(text=f"Frame: {self.current_frame}/{self.total_frames-1}")
            
            # Increment frame counter if playing
            if self.playing:
                self.current_frame = (self.current_frame + 1) % self.total_frames
                
        except Exception as e:
            logging.error(f"Error updating displays: {e}")
            
    def prepare_photo(self, frame):
        """Safely convert frame to PhotoImage"""
        try:
            frame = cv2.resize(frame, (320, 240))
            image = Image.fromarray(frame)
            return ImageTk.PhotoImage(image)
        except Exception as e:
            logging.error(f"Error preparing photo: {e}")
            return None
            
    def update_original_display(self, frame):
        """Update original video display"""
        try:
            frame_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            photo = self.prepare_photo(frame_rgb)
            if photo:
                self.original_canvas.create_image(0, 0, image=photo, anchor=tk.NW)
                self.original_canvas.photo = photo
        except Exception as e:
            logging.error(f"Error updating original display: {e}")

    def update_vitpose_display(self, frame):
        """Update ViTPose output display with skeleton visualization."""
        try:
            if self.vitpose_wrapper:
                # Create display frame based on view state
                if not self.view_states['vitpose']['show_background']:
                    display_frame = np.zeros(frame.shape, dtype=np.uint8)
                else:
                    display_frame = frame.copy()

                # Run ViTPose inference
                keypoints = self.vitpose_wrapper.process_frame(frame)
                
                if keypoints is not None and len(keypoints) > 0:
                    # Get preprocessing metadata
                    _, img_metas = self.vitpose_wrapper.preprocess_frame(frame)
                    if img_metas is None:
                        return
                        
                    meta = img_metas[0]
                    scale_factor = meta['scale_factor']  # [width_scale, height_scale]

                    # Scale keypoints back to original frame size
                    original_keypoints = []
                    for kp in keypoints:
                        orig_x = int(kp[0] * scale_factor[0])  # Scale x coordinate
                        orig_y = int(kp[1] * scale_factor[1])  # Scale y coordinate
                        original_keypoints.append((orig_x, orig_y, kp[2]))  # Keep confidence score

                    # Draw skeleton
                    confidence_threshold = 0.3
                    for connection in self.vitpose_wrapper.keypoint_connections:
                        pt1_idx, pt2_idx = connection
                        if (original_keypoints[pt1_idx][2] > confidence_threshold and
                                original_keypoints[pt2_idx][2] > confidence_threshold):
                            pt1 = tuple(map(int, original_keypoints[pt1_idx][:2]))
                            pt2 = tuple(map(int, original_keypoints[pt2_idx][:2]))
                            color = (255, 255, 255) if not self.view_states['vitpose']['show_background'] else (0, 255, 0)
                            cv2.line(display_frame, pt1, pt2, color, 2)

                    # Draw keypoints
                    for x, y, conf in original_keypoints:
                        if conf > confidence_threshold:
                            color = (255, 255, 255) if not self.view_states['vitpose']['show_background'] else (255, 0, 0)
                            cv2.circle(display_frame, (int(x), int(y)), 4, color, -1)

                # Convert frame for display
                photo = self.prepare_photo(cv2.cvtColor(display_frame, cv2.COLOR_BGR2RGB))
                if photo:
                    self.vitpose_canvas.create_image(0, 0, image=photo, anchor=tk.NW)
                    self.vitpose_canvas.photo = photo

        except Exception as e:
            logging.error(f"Error updating ViTPose display: {e}")
    # def update_wham_display(self, frame):
    #     """Update WHAM output display with toggle support"""
    #     try:
    #         if not self.view_states['wham']['show_background']:
    #             display_frame = np.zeros(frame.shape, dtype=np.uint8)
    #         else:
    #             display_frame = frame.copy()
                
    #         # Add WHAM processing here
    #         # Similar to MediaPipe, draw skeleton/mesh on either blank or original background
            
    #         photo = self.prepare_photo(cv2.cvtColor(display_frame, cv2.COLOR_BGR2RGB))
    #         if photo:
    #             self.wham_canvas.create_image(0, 0, image=photo, anchor=tk.NW)
    #             self.wham_canvas.photo = photo
                
    #     except Exception as e:
    #         logging.error(f"Error updating WHAM display: {e}")

    def update_mediapipe_display(self, frame):
        """Update MediaPipe output display with toggle support"""
        try:
            if self.mediapipe_pose:
                # Create display frame based on toggle state
                if not self.view_states['mediapipe']['show_background']:
                    display_frame = np.zeros(frame.shape, dtype=np.uint8)
                else:
                    display_frame = frame.copy()

                # Process with MediaPipe
                results = self.mediapipe_pose.process(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
                
                if results.pose_landmarks:
                    if not self.view_states['mediapipe']['show_background']:
                        # White skeleton on black background
                        self.mp_drawing.draw_landmarks(
                            display_frame,
                            results.pose_landmarks,
                            self.mp_pose.POSE_CONNECTIONS,
                            landmark_drawing_spec=self.mp_drawing.DrawingSpec(
                                color=(255, 255, 255),
                                thickness=2,
                                circle_radius=2
                            ),
                            connection_drawing_spec=self.mp_drawing.DrawingSpec(
                                color=(255, 255, 255),
                                thickness=2
                            )
                        )
                    else:
                        # Colored skeleton on video
                        self.mp_drawing.draw_landmarks(
                            display_frame,
                            results.pose_landmarks,
                            self.mp_pose.POSE_CONNECTIONS
                        )
                
                # Convert and display the processed frame
                photo = self.prepare_photo(cv2.cvtColor(display_frame, cv2.COLOR_BGR2RGB))
                if photo:
                    self.mediapipe_canvas.create_image(0, 0, image=photo, anchor=tk.NW)
                    self.mediapipe_canvas.photo = photo
                    
        except Exception as e:
            logging.error(f"Error updating MediaPipe display: {e}")

    def update_fourdhuman_display(self, frame):
        """Update 4DHuman output display with toggle support"""
        try:
            if not self.view_states['4dhuman']['show_background']:
                display_frame = np.zeros(frame.shape, dtype=np.uint8)
            else:
                display_frame = frame.copy()
            display_frame = self.FDHmodel.get_display_frame(frame)

            photo = self.prepare_photo(cv2.cvtColor(display_frame, cv2.COLOR_BGR2RGB))
            if photo:
                self.fourdhuman_canvas.create_image(0, 0, image=photo, anchor=tk.NW)
                self.fourdhuman_canvas.photo = photo
                
        except Exception as e:
            logging.error(f"Error updating 4DHuman display: {e}")
            
    def play(self):
        """Play video with error handling"""
        try:
            if self.playing and self.cap is not None:
                self.update_frame()
                self.update_id = self.root.after(self.update_interval, self.play)
        except Exception as e:
            logging.error(f"Error during playback: {e}")
            self.playing = False
            
    def prev_frame(self):
        """Go to previous frame"""
        if self.cap is None:
            return
        self.current_frame = max(0, self.current_frame - 1)
        self.update_frame()
        
    def next_frame(self):
        """Go to next frame"""
        if self.cap is None:
            return
        self.current_frame = min(self.total_frames - 1, self.current_frame + 1)
        self.update_frame()
        
    def cleanup(self):
        """Clean up resources"""
        try:
            if self.cap is not None:
                self.cap.release()
            if self.update_id:
                self.root.after_cancel(self.update_id)
            self.root.quit()
        except Exception as e:
            logging.error(f"Error during cleanup: {e}")

# %%
vitpose_weights_path = './checkpoints/vitpose_checkpoint.pth'
vitpose_config_path = 'ViTPose/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/coco/vitPose+_large_coco+aic+mpii+ap10k+apt36k+wholebody_256x192_udp.py'
# vitpose_config_path = 'ViTPose/configs/body/2d_kpt_sview_rgb_img/topdown_heatmap/coco/vitPose+_base_coco+aic+mpii+ap10k+apt36k+wholebody_256x192_udp.py'

# %%
def main():
    # Configure logging
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s'
    )
    
    try:
        root = tk.Tk()
        app = PoseEstimationUI(root, vitpose_weights_path=vitpose_weights_path, vitpose_config_path = vitpose_config_path)
        root.protocol("WM_DELETE_WINDOW", app.cleanup)
        root.mainloop()
    except Exception as e:
        logging.error(f"Fatal error: {e}")
        sys.exit(1)

# %%
main()
# Out:
# Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v2.4.0. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../.cache/4DHumans/logs/train/multiruns/hmr2/0/checkpoints/epoch=35-step=1000000.ckpt`
# 2024-12-08 09:20:16,249 - ERROR - Failed to initialize 4DHuman model: cannot import name 'OSMesaCreateContextAttribs' from 'OpenGL.osmesa' (/home/bizon/anaconda3/envs/posecompare/lib/python3.10/site-packages/OpenGL/osmesa/__init__.py)
# 2024-12-08 09:20:16,250 - ERROR - Failed to initialize 4DHumans: cannot import name 'OSMesaCreateContextAttribs' from 'OpenGL.osmesa' (/home/bizon/anaconda3/envs/posecompare/lib/python3.10/site-packages/OpenGL/osmesa/__init__.py)
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733667616.541856 3988874 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1733667616.664248 4003010 gl_context.cc:357] GL version: 3.2 (OpenGL ES 3.2 NVIDIA 560.35.03), renderer: NVIDIA GeForce RTX 4090/PCIe/SSE2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1733667616.749230 4002990 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1733667616.864397 4002982 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Use load_from_local loader
# 2024-12-08 09:20:24,417 - INFO - ViTPose model initialized successfully.
# W0000 00:00:1733667632.157647 4002989 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# 2024-12-08 09:20:32,408 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:34,656 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:34,818 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:34,978 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:35,136 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:35,306 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:35,468 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:35,629 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:35,786 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:35,949 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:36,112 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:36,278 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:36,438 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:36,611 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:36,773 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:36,936 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:37,096 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:37,261 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:37,427 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:37,594 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:37,759 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:37,923 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:38,093 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:38,257 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:38,422 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:38,589 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:38,756 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:38,920 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:39,087 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:39,251 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:39,418 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:39,580 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:39,739 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:39,904 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:40,071 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:40,237 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:40,399 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:40,563 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:40,730 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:40,894 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:41,060 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:41,222 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:41,384 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:41,549 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:41,711 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:41,876 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:42,048 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:42,214 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:42,378 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:42,541 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:42,708 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:42,871 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:43,081 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:43,247 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:43,412 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:43,583 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:43,755 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:43,928 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:44,100 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:44,265 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:44,433 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:44,603 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:44,746 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:44,881 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:45,044 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:45,209 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:45,370 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:45,534 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:45,698 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:45,858 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:46,023 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:46,183 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:46,342 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:46,503 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:46,667 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:46,843 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:47,085 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:47,250 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:47,414 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:47,577 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:47,738 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:47,903 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:48,068 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:48,220 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:48,351 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:48,524 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:48,635 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:48,747 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:48,863 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:48,981 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:49,092 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:49,264 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:49,442 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:49,604 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:49,763 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:49,929 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:50,091 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:50,250 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:50,419 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:50,586 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:50,752 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:50,917 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:51,085 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:51,249 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:51,416 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:51,557 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:51,692 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:51,858 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:52,022 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:52,190 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:52,355 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:52,523 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:52,689 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:52,861 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:53,025 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:53,188 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:53,353 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:53,521 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:53,686 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:53,847 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:53,989 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:54,124 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:54,290 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:54,453 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:54,620 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:54,786 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:54,956 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:55,121 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:55,290 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:55,452 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:55,616 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:55,781 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:55,953 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:56,117 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:56,285 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:56,449 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:56,613 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:56,776 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:56,948 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:57,115 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:57,281 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:57,453 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:57,626 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:57,800 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:57,969 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:58,130 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:58,297 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:58,466 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:58,643 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:58,806 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:59,056 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:59,223 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:59,386 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:59,556 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:59,718 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:20:59,886 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:00,053 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:00,219 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:00,383 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:00,547 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:00,676 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:00,838 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:00,998 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:01,159 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:01,321 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:01,485 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:01,650 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:01,811 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:01,972 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:02,134 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:02,298 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:02,461 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:02,629 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:02,791 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:03,055 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:03,216 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:03,380 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:03,546 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:03,710 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:03,884 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:04,050 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:04,213 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:04,404 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:04,539 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:04,703 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:04,860 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:05,026 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:05,191 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:05,354 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:05,518 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:05,684 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:05,843 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:06,011 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:06,175 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:06,341 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:06,595 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:06,760 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:06,926 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:07,088 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:07,256 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:07,423 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:07,590 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:07,754 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:07,918 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:08,115 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:08,247 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:08,404 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:08,571 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:08,728 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:08,890 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:09,050 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:09,214 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:09,374 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:09,534 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:09,695 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:09,939 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:10,052 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:10,163 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:10,280 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:10,395 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:10,507 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:10,619 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:10,735 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:10,850 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:10,965 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:11,083 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:11,198 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:11,314 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:11,428 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:11,603 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:11,770 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:11,944 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:12,107 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:12,273 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:12,457 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:12,588 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:12,749 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:12,915 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:13,076 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:13,235 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:13,398 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:13,560 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:13,728 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:13,888 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:14,055 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:14,214 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:14,376 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:14,539 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:14,703 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:14,866 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:15,029 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:15,168 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:15,303 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:15,466 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:15,632 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:15,791 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:15,953 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:16,120 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:16,284 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:16,453 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:16,620 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:16,753 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:16,890 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:17,053 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:17,224 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:17,387 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:17,549 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:17,710 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:17,873 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:18,035 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:18,196 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:18,359 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:18,521 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:18,685 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:18,847 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:19,010 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:19,178 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:19,420 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:19,588 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:19,760 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:19,923 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:20,086 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:20,248 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:20,407 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:20,574 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:20,736 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:20,897 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:21,059 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:21,219 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:21,413 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:21,577 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:21,746 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:21,911 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:22,079 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:22,242 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:22,403 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:22,566 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:22,730 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:22,891 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:23,058 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:23,226 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:23,389 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:23,566 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:23,733 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:23,898 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:24,060 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:24,225 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:24,396 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:24,565 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:24,731 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:24,893 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:25,054 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:25,219 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:25,409 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:25,573 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:25,737 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:25,903 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:26,066 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:26,229 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:26,391 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:26,557 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:26,720 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:26,883 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:27,048 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:27,214 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:27,378 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:27,539 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:27,700 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:27,866 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:28,030 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:28,192 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:28,353 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:28,516 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:28,681 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:28,836 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:28,993 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:29,144 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:29,301 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:29,456 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:29,610 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:29,763 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:29,915 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:30,068 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:30,223 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:30,374 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:30,528 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:30,684 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:30,838 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:30,993 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:31,148 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:31,314 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:31,467 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:31,619 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:31,773 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:31,926 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:32,087 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:32,243 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:32,398 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:32,553 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:32,710 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:32,862 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:33,014 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:33,168 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:33,320 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:33,477 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:33,633 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:33,786 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:33,942 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:34,096 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:34,249 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:34,405 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:34,596 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:34,749 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:34,912 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:35,065 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:35,219 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:35,374 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:35,525 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:35,681 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# 2024-12-08 09:21:35,832 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:36,107 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:36,326 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:36,575 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:36,825 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:37,075 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:37,323 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:37,567 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:37,814 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:38,061 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:38,314 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:38,559 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:38,806 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:39,054 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:39,299 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:39,546 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:39,797 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:40,051 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:40,390 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:40,729 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# [h264 @ 0x599ce1812600] co located POCs unavailable
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:41,072 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# [h264 @ 0x599ce1898940] co located POCs unavailable
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:41,409 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:41,745 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:42,083 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# [h264 @ 0x599ce1812600] co located POCs unavailable
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:42,419 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# [h264 @ 0x599ce1898940] co located POCs unavailable
# [h264 @ 0x599d8679e340] mmco: unref short failure
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:42,753 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# [h264 @ 0x599d865e5340] mmco: unref short failure
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:43,188 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599ce1812600] mmco: unref short failure
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:43,616 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# [h264 @ 0x599ce1898940] mmco: unref short failure
# [h264 @ 0x599ce1812600] co located POCs unavailable
# [h264 @ 0x599cea489780] co located POCs unavailable
# [h264 @ 0x599ce1812600] co located POCs unavailable
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:44,044 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# [h264 @ 0x599cea489780] co located POCs unavailable
# [h264 @ 0x599ce1898940] co located POCs unavailable
# [h264 @ 0x599d8679e340] mmco: unref short failure
# [h264 @ 0x599cea489780] co located POCs unavailable
# [h264 @ 0x599ce1898940] co located POCs unavailable
# [h264 @ 0x599cea489780] co located POCs unavailable
# 2024-12-08 09:21:44,468 - ERROR - Error updating 4DHuman display: 'NoneType' object has no attribute 'get_display_frame'
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 main()
#
# Cell In[12], line 12, in main()
#      10     app = PoseEstimationUI(root, vitpose_weights_path=vitpose_weights_path, vitpose_config_path = vitpose_config_path)
#      11     root.protocol("WM_DELETE_WINDOW", app.cleanup)
# ---> 12     root.mainloop()
#      13 except Exception as e:
#      14     logging.error(f"Fatal error: {e}")
#
# File ~/anaconda3/envs/posecompare/lib/python3.10/tkinter/__init__.py:1458, in Misc.mainloop(self, n)
#    1456 def mainloop(self, n=0):
#    1457     """Call the mainloop of Tk."""
# -> 1458     self.tk.mainloop(n)
#
# KeyboardInterrupt:
